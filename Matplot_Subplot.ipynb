# %%
#import required libraries
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
#define tmp,wind,humidity,precipitation data
temp_data =[12,14,6,67,89,90,45,43,56,78]
wind_data =[14,18,23,45,67,89,32,44,88,99]
time_hrs =[1,4,5,6,7,8,9,9,12,13]
humidity_dat =[21,23,4,67,87,98,76,65,54,34]
precipitation_data =[26,23,24,34,5,6,7,7,53]

# %%
#draw subplots for (1,2,1) and 1,2,2)
plt.figure(figsize=(8,4))
plt.subplots_adjust(hspace =0.25)
plt.subplot(1,2,1)
plt.title('temp')
plt.plot(time_hrs,temp_data,color ='b',linestyle ='-',linewidth =1)
plt.subplot(1,2,2)
plt.title('Wind')
plt.plot(time_hrs,wind_data,color ='r',linestyle ='-',linewidth =1)

# %%
#draw subplots for (2,1,1) and (2,1,2)
plt.figure(figsize=(8,4))
plt.subplots_adjust(hspace =0.25)
plt.subplot(2,1,1)
plt.title('temp')
plt.plot(time_hrs,temp_data,color ='b',linestyle ='-',linewidth =1)
plt.subplot(2,1,2)
plt.title('Wind')
plt.plot(time_hrs,wind_data,color ='r',linestyle ='-',linewidth =1)

# %%
#draw subplots for (2,2,1) and (2,2,2),(2,2,3) and(2,2,4)

plt.figure(figsize=(8,14))
plt.subplots_adjust(hspace=0.3)
plt.subplot(2,2,1)
plt.title('Temp(F)')
plt.plot(time_hrs,temp_data,color ='b',linestyle ='-',linewidth =1)
plt.subplot(2,2,2)
plt.title('Wind')
plt.plot(time_hrs,wind_data,color ='r',linestyle ='-',linewidth =1)
plt.subplot(2,2,3)
plt.title('Temp(F)')
plt.plot(time_hrs,temp_data,color ='b',linestyle ='-',linewidth =1)
plt.subplot(2,2,4)
plt.title('Wind')
plt.plot(time_hrs,wind_data,color ='r',linestyle ='-',linewidth =1)
